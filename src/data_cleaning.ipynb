# %% [markdown]
# # ADA 2018 -  Evolution of Music.
#
# #### Andres Montero, Ariel Alba, Diego Iriarte

# %% [markdown]
# This project aims to find the relationships between tweets and music, specifically focus on tweets which reflect a positive sentiment or mood and we'll relate them to the kind of music those people listen to. We believe that music preferences vary depending on people's mood, so we can detect what kind of music people tend to listen to when they are feeling happy or posting tweets with positive sentiment, which in our case are equivalent.
# For it, we'll work with two datasets:
#
# * FMA: A Dataset For Music Analysis
# * Sentiment140 dataset with 1.6 million tweets
#
# Tweets dataset is a labeled set, indicating whether each tweet has a positive sentiment or not.
# In order to define whether the proposed idea is feasible or not, we follow these steps:
#
# **A)** Preprocessing and analyzing FMA dataset. Gather the data that will be used, the dataset is very extense and we must focus on the data that will be used for our study. We clean the data, define the type of variables, normalize them and deal with missing values. From the cleaned data, we get some statistical information of the dataset, such as most listened songs, albums and others. We try to find some relationships between some information of the dataset such as: danceability, energy, number of times listened, location and others, too.
#
# **B)** Loading and analyzing of Sentiment140 dataset. We will only focus on tweets which are labeled as positive sentiment and the approach. The dataset contains few information about the tweets such as date, sentiment, userID and tweet, and is limited to tweets of yar 2009. Before doing any further preprocessing of such dataset we decided to check the possible relationships that we could find with FMA dataset.
#
# **C)** Find relationships between both datasets. It is important to identify whether the idea of the project is feasible or not. For the idea to be feasible, we need to find a considerable number of positive tweets which are somehow related to music or songs. To measure this relationships our approach is the following:
#
# * Count how many tweets are linked to a song
# * Count how many tweets explicitly say spotify on it.
# * Find words related to music contained in the tweets (may be a difficult task)
#
# **D)** In case, our two first approaches to find the relationships between both datasets don't succeed, we may not be able to try with the third one due to time contraints and task difficulty. If this is the scenario, the project scope will be reduced and will mostly focus on the FMA dataset and a specific event in the past years which may caused an impact on music production and preferences. Such scenario will be defined according to the insights found in part A.

# %%
% matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import reverse_geocoder as rg
import os.path
import ast
import seaborn as sns

from helpers import *
from datetime import datetime, date, time
from scipy import stats

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### A) Preprocessing and Analyzing FMA Dataset

# %% [markdown]
# First part consists of loading the data that is needed for the analysis, cleaning and storing them in dataFrames so we can further work with them.
#
# First, we will define some constants and paths that will help us later.

# %%
# Constants
DATA_DIR = '../data/'
MUSIC_DIR = '{dir}{file}/'.format(dir=DATA_DIR, 
                                  file='fma_metadata')
PKL_DIR = '{dir}{file}/'.format(dir=DATA_DIR, 
                               file='pkl')

# True if we want to to execute the clean phase and to force 
# saving the cleaned file
CLEAN_PHASE = True
DEBUG = True

# %%
if CLEAN_PHASE:
    echonest_path = '{dir}{file}'.format(dir=MUSIC_DIR, 
                                         file='echonest.csv')
    features_path = '{dir}{file}'.format(dir=MUSIC_DIR,
                                         file='features.csv')
    genres_path = '{dir}{file}'.format(dir=MUSIC_DIR,
                                       file='genres.csv')
    tracks_path = '{dir}{file}'.format(dir=MUSIC_DIR,
                                       file='tracks.csv')

# %% [markdown]
# By looking at the FMA dataset we find out that metadata csv file is full of unnecesary information for our analysis.
#
# Thus, we define which variables, type of variables and name of columns we are going to extract from the FMA csv files.

# %%
if CLEAN_PHASE:
    # Load datasets into pandas dataframes
    echonest_col_names=['track_id', 'danceability', 'energy',
                        'valence', 'artist_latitude',
                        'artist_longitude', 'artist_name',
                        'artist_discovery', 'artist_family',
                        'artist_hotness', 'song_currency', 
                        'song_hotness']
    
    echonest_dtypes = {'track_id': int, 'danceability': float, 
                       'energy': float, 'valence': float,
                       'artist_latitude': float, 'artist_longitude': float,
                       'artist_name': str, 'artist_discovery': float, 
                       'artist_family': float, 'artist_hotness': float,
                       'song_currency': float, 'song_hotness': float}
    
    echonest_df = pd.read_csv(echonest_path, names=echonest_col_names,
                              header=3, dtype=echonest_dtypes, 
                              usecols=[0, 2, 3, 8, 11, 13, 14,
                                       21, 22, 23, 24, 25])

    genres_dtypes = {'genre_id': int, '#tracks': int, 
                     'parent': int, 'top_level': int}
    
    genres_df = pd.read_csv(genres_path, dtype=genres_dtypes)
    
    track_col_names = ['track_id', 'album_date_created',
                       'album_date_released', 'album_id',
                       'album_listens', 'album_title', 
                       'artist_id', 'artist_latitude',
                       'artist_longitude', 'artist_name',
                       'track_duration', 'track_genre_top',
                       'track_genres_all', 'track_language', 
                       'track_listens', 'track_tags', 
                       'track_title']

    tracks_dtypes = {'track_id': int, 'album_date_created': str,
                     'album_date_released': str, 
                     'album_id': int, 'album_listens': int, 
                     'album_title': str, 'artist_id': int,
                     'artist_latitude': float, 'artist_longitude': float,
                     'artist_name': str, 'track_duration': int, 
                     'track_genre_top': str, 'track_genres_all': str, 
                     'track_language': str, 'track_listens': int,
                     'track_tags': str, 'track_title': str}

    tracks_df = pd.read_csv(tracks_path, names=track_col_names,
                            header=2, usecols=[0, 2, 3, 6, 8, 11,
                                               21, 22, 24, 26, 38, 
                                               40, 41, 45, 47, 51,
                                               52])
    track_genre_rel_df = pd.DataFrame(columns=['track_id', 'genre_id'])

# %% [markdown]
# Right now, we have 3 dataframes: echonest, tracks and genres which makes reference to the csv files.
#
# Now, it is time to clean data!!! And have some information in a more suitable represetation for further analysis.
#
# First we start cleaning tracks dataframe.

# %%
# Tracks clean phase
if CLEAN_PHASE:
    
    # Transforms str to datetime
    tracks_df['album_date_released'] = pd.to_datetime( \
                                            tracks_df['album_date_released'])
    tracks_df['album_date_created'] = pd.to_datetime( \
                                            tracks_df['album_date_created'])
    # Transform str to list
    tracks_df['track_tags'] = tracks_df['track_tags'] \
                                .apply(lambda x: ast.literal_eval(x))
    tracks_df['track_genres_all'] = tracks_df['track_genres_all'] \
                                        .apply(lambda x: ast.literal_eval(x))
    
    # Generate track-genre relational dataframe
    track_genre_tuple = list(zip(tracks_df['track_id'], 
                             tracks_df['track_genres_all']))
    track_genre_list = [{'track_id': track_id, 'genre_id': genre_id} 
                         for track_id, genres_id in track_genre_tuple
                         for genre_id in genres_id]

    track_genre_rel_df = track_genre_rel_df.append(track_genre_list, 
                                                   ignore_index=True,
                                                   sort=False)

# %% [markdown]
# We realize that the tracks dataframe contains also information about artists and albums and echonest has information for each track , thus, to have a better organization and not have redundacy, we joined tracks and echonest. Then the joined table was split on 3 new dataframes: tracks, albums and artists.

# %%
if CLEAN_PHASE:
    # Normalize dataframes to take out redundancy
    # Join echonist data to tracks
    echo_tracks = echonest_df.merge(tracks_df, left_on='track_id', 
                                    right_on='track_id', how='outer')
    
    print(len(echo_tracks))
     
    # Select main columns to create new df
    artists_df = echo_tracks[['artist_id', 'artist_name_x',
                              'artist_latitude_x', 'artist_longitude_x', 
                              'artist_discovery', 'artist_family', 
                              'artist_hotness', 'artist_latitude_y',
                              'artist_longitude_y', 'artist_name_y']].copy()

    albums_df = echo_tracks[['album_id', 'album_date_created',
                             'album_date_released', 'album_title',
                             'album_listens']].copy()
    
    tracks_df = echo_tracks[['track_id', 'track_title', 
                             'track_duration', 'artist_id', 
                             'album_id', 'track_genre_top',
                             'track_genres_all','track_language',
                             'track_listens', 'track_tags',
                             'danceability', 'energy',
                             'valence', 'song_currency',
                             'song_hotness']].copy()
    
    # Drop duplicates
    artists_df = artists_df.drop_duplicates('artist_id')
    albums_df = albums_df.drop_duplicates('album_id')
    
    # Reset Index
    artists_df = artists_df.reset_index(drop=True)
    albums_df = albums_df.reset_index(drop=True)
    
    # Clean listen count
    albums_df['album_listens'] = albums_df['album_listens'] \
                                    .apply(lambda x : neg_to_zero(x))
    
    tracks_df['track_listens'] = tracks_df['track_listens'] \
                                    .apply(lambda x : neg_to_zero(x))
    
    
    # Include genre_parent column in genres_df
    genres_df1=genres_df.set_index('genre_id')
    new_genre = [genres_df1.at[int(top_genre), 'title'] for top_genre in genres_df.top_level]
    genres_df=genres_df.assign(genre_parent=new_genre)
    
    # Artist name different on echonest and FullMusicArchive
    if DEBUG:
        name_comp = not_eq_ign_case(artists_df['artist_name_x'],
                                    artists_df['artist_name_y'])
        artist_name_diff = artists_df[name_comp]
        
        print('# Different artist names: {}\n' \
                  .format(len(artist_name_diff)))

        print('Example:\n{}'.format(artist_name_diff[['artist_name_x',
                                                      'artist_name_y']].head(3)))
# Out:
# 106574
# # Different artist names: 13797
#
# Example:
#                         artist_name_x                    artist_name_y
# 2   Alec K. Redfearn and the Eyesores  Alec K. Redfearn & the Eyesores
# 26                      From Quagmire                        Dora Bleu
# 31                     Marc A. Pullen                          Fanatic

# %% [markdown]
# Finally we have 4 main datasets: genres, artists, albums and tracks.
#
# FMA dataset (https://lts2.epfl.ch/datasets/fma/) was gathered by joining a lot of information of many music API services like Echonest(now Spotify), LastFM, MusicBrainz and others more, thus, there are some columns that have data redundacy.

# %%
# Artist location different on echonest and FullMusicArchive
if DEBUG and CLEAN_PHASE:
    lat_comp = artists_df['artist_latitude_x'] != artists_df['artist_latitude_y']
    long_comp = artists_df['artist_longitude_x'] != artists_df['artist_longitude_y']
    latlong_comp = lat_comp | long_comp
    latlong_diff = artists_df[latlong_comp]

    print('# Different Lat Long values: {}\n' \
              .format(len(latlong_diff)))

    print('Example:\n{}'.format(artist_name_diff[['artist_latitude_x',
                                                  'artist_latitude_y',
                                                  'artist_longitude_x',
                                                  'artist_longitude_y']].head(3)))
# Out:
# # Different Lat Long values: 16339
#
# Example:
#     artist_latitude_x  artist_latitude_y  artist_longitude_x  \
# 2             41.8239          41.823989            -71.4120
# 26                NaN                NaN                 NaN
# 31            40.7978                NaN            -81.3716
#
#     artist_longitude_y
# 2           -71.412834
# 26                 NaN
# 31                 NaN

# %% [markdown]
# Also there is some spatial information encoded on certain columns, to handle them, we used a service to retrieve the exact location (Country, city, state).

# %%
if CLEAN_PHASE:
    # Getting city, state, country from artist longitude and latitude
    cities=[]
    states=[]
    countries=[]
    
    for i in range (0, len(artists_df)):
        if np.isnan(artists_df.artist_latitude_y[i]):
            city = np.nan
            state = np.nan
            country = np.nan
        else:
            coordinates = (artists_df.artist_latitude_y[i], 
                           artists_df.artist_longitude_y[i])
            results = rg.search(coordinates, mode=1)
            city = results[0]['name']
            state = results[0]['admin1']
            country = results[0]['cc']
        
        cities.append(city)
        states.append(state)
        countries.append(country)
    
    artists_df.insert(loc=5, column='city', 
                      value=pd.Series(cities))
    artists_df.insert(loc=6, column='state',
                      value=pd.Series(states))
    artists_df.insert(loc=7, column='country', 
                      value=pd.Series(countries))
# Out:
# Loading formatted geocoded file...

# %% [markdown]
# #### Dataset from Spotify

# %%
# Data from Spitfy and LastFM API with updated information
YEARS = [2015, 2016, 2017, 2018]
dfs = {}

for year in YEARS:
    albums_year_path = '{dir}albums_{year}_df.pkl'.format(dir=PKL_DIR,
                                                          year=year)
    artists_year_path = '{dir}artists_{year}_df.pkl'.format(dir=PKL_DIR,
                                                            year=year)
    tracks_year_path = '{dir}tracks_{year}_df.pkl'.format(dir=PKL_DIR,
                                                          year=year)

    dfs[year] = {'tracks': pd.read_pickle(tracks_year_path),
                 'albums': pd.read_pickle(albums_year_path),
                 'artists': pd.read_pickle(artists_year_path)}

# %%
if CLEAN_PHASE:
    tracks_post = pd.DataFrame(columns=tracks_df.columns) 
    albums_post = pd.DataFrame(columns=albums_df.columns)
    artists_post = pd.DataFrame(columns=artists_df.columns)
    result = []
    
    for index, year in enumerate(YEARS):
        tracks = dfs[year]['tracks']
        albums = dfs[year]['albums']
        artists = dfs[year]['artists']
        # Sample
        if(year == 2015):
            tracks = tracks.sample(frac=0.375)
            albums = albums.sample(frac=0.10)
            artists = artists.sample(frac=0.175)
        elif(year == 2016):
            tracks = tracks.sample(frac=0.50)
            albums = albums.sample(frac=0.125)
            artists = artists.sample(frac=0.175)
        elif(year == 2017):
            tracks = tracks.sample(frac=0.80)
            albums = albums.sample(frac=0.20)
            artists = artists.sample(frac=0.175)
        elif(year == 2018):
            tracks = tracks.sample(frac=0.90)
            albums = albums.sample(frac=0.225)
            artists = artists.sample(frac=0.175)
        
        # New tracks cleaning
        # Transform miliseconds duration to minutes
        tracks['track_duration'] = tracks['track_duration'] / 60000

        # Normalize song_hotness to be a value between 1 and 0
        tracks['song_hotness'] = tracks['song_hotness'] / 100 

        # New albums cleaning
        albums['album_date_released'] = pd.to_datetime( \
                                                albums['album_date_released'])

        # New artist cleaning
        # Normalize artist_hotness to be a value between 1 and 0
        artists['artist_hotness'] = artists['artist_hotness'] / 100

        # Merge the datasets of all years to have just one dataset for tracks ,
        # albums and artists
        tracks_post = pd.concat([tracks_post, tracks], axis=0, 
                                sort=False)
        artists_post = pd.concat([artists_post, artists], axis=0, 
                                 sort=False)
        albums_post = pd.concat([albums_post, albums], axis=0, 
                                sort=False)
        
    # Drop duplicates
    tracks_post.drop_duplicates('track_id', inplace=True)
    artists_post.drop_duplicates('artist_id', inplace=True)
    albums_post.drop_duplicates('album_id', inplace=True)
    

    
    # Generate relational dataframe track-genres
    # Look at genres on tags and add them to track_genres_all
    genre_list = genres_df['title'].tolist()
    genres = [genre.lower() for genre in genre_list]

    for i, row in tracks_post.iterrows():
        genre_set = set(genres)
        tag_set = set(row['track_tags'])
        genres_from_tags = list(genre_set.intersection(tag_set))
        track_uniq_genres = uniq(row['track_genres_all'] + genres_from_tags)
        [result.append({'track_id': row['track_id'],
                        'genre_name': genre}) for genre in track_uniq_genres]
    
    genres_merge = genres_df.copy()
    genres_merge['title'] = genres_merge['title'].str.lower()
    track_genre_name = pd.DataFrame(data=result)
    track_genre_name['genre_name'] = track_genre_name['genre_name'].str.lower()
    track_genre_rel_post = track_genre_name.merge(genres_merge, left_on='genre_name',
                                                right_on='title')[['track_id', 'genre_id']]

# %%
tracks_post
# Out:
#                       track_id  \
# 64851   32WCcSindDy2AKj1IdV2aE
# 84465   0aOoS0SpzGRnDXmuVbiCPZ
# 4042    6g7amHSbqmmk7fpViGqXb3
# 82084   60OwwNiAIeoe8533hk0USo
# 55396   41eHsMDXaqizJxLYI9AkFa
# 55052   3QesnFSEEgZ1wwyox1ne1f
# 70395   1PXIsSyC3YSAtuI0U9dTRk
# 19831   530J9GupahE2O4a1iVkQxB
# 75702   0qNbCmjavn69YUdV4c1BDn
# 20847   5HhQMt1RKJZCY1FbNw6Od6
# 2111    00z2Nm4cLt0mIKOGF6uZfl
# 57631   3HMXjw4O10Fz3yTTZpNrmX
# 68269   3onluLeinePPcyzD2LdNHX
# 65476   5CSDxDQtEA3oWJzByQRi0i
# 84475   5B78uuKzDVzOh4iUfE1ySz
# 78215   5ich0wSxDxMryEjwZo6XzG
# 41616   09pndptriN0JkMSkGVpqGd
# 24341   3TpRg6slHq8FBa4zoqE6Pq
# 69577   2WemESiMErYvMjvJ1biqHN
# 101089  3Z4bS2ASZuYYt7KsvRPvxQ
# 53260   673vzVv1oakQB3DmTZTIB4
# 67807   4fFWKcB0x0aKAq18LvEYf5
# 61400   5PIn3fUqldKcNA2nMFLGfR
# 29105   5FpdDLWtWBuqngEEcq2Pg4
# 67373   2ztG2mzaBr65XWQR2WUGm0
# 96831   7ElqtwxhSQbBTgnn8o3Q2A
# 100848  11MJ2frnel6kutVlFSQm1h
# 27300   26PeMFQLMwaLwc5KhIkeWg
# 36944   5Zo6BAGPRLeTFx0Z0y4usT
# 46007   162eGiet5rEIiTTcL50qTw
# ...                        ...
# 8601    05bUAkDRK3xzvVkZlGU6ee
# 51624   6jJljsgRRpyuXKxZGeW6Vy
# 24011   4DHHDoVqLylUi1KBTtgytf
# 27117   6neCPzADon669Mxe4oZSlR
# 15673   25NyJoTBGJHVFTfw4J1ONU
# 25      1dUHF4RyMmMTveJ0Rby6Xm
# 57296   4Au6ZWmhUr3iLMzcjvg9cu
# 4287    2Z8SpRWDcWCrRBBoX6z80Z
# 51526   5RPTJWrqbU5DK2O5MAbUHN
# 44844   4RXbeqy6x25h4xCYNHp4dc
# 66320   039Doul5oJK7LoMmwj0MD4
# 31303   7riVWDCXzmFlOjhFzkr3ed
# 42583   4MAMTDNaTiFrdWkO9gxj2a
# 5597    5iXW7gPQuDz5GCVJT8fjJl
# 67611   4upqEezZn96B2A8nLdHKQw
# 15853   4sOFRu2UsAlYnFZOw06glP
# 55109   6EwRpLL5QThnF2k1sZzQpC
# 46653   0KpXBGMi5TPHu8cJGWvNBb
# 51467   5ArtaQ740g1HgDugVOyzf7
# 22604   6p3MquVmVPXgH5WrRYoTL8
# 1398    0dY2cWiCvcBs6lW5UOAOIB
# 52780   5MIUtrizeyaYjpKwKCWJ5C
# 59502   6iXRiBqfLeZClOJsGqRazw
# 51717   0u5Mj8mkmdxwjERBFRq4QO
# 18133   4rPtxv6E6qAdtJoTko4Cef
# 35165   37dHBMBKyHrxpFbxBmkYgA
# 15665   1mmH9ECjDEylMivA5Q34CW
# 49501   3TbcNUywObI43xqo2dLaX8
# 67565   5HmFxJMotmP3ZUCyh9AY0j
# 5587    6seVUEUDm3XQYkWqK1vWiW
#
#                                               track_title track_duration  \
# 64851                                               Lover         2.5571
# 84465                                        Mighty Mouse       0.528667
# 4042                                               Wolves         4.1051
# 82084                                                Eyes        4.08725
# 55396                                 Entre ciel et terre        2.63177
# 55052                          Not Tomorrow (Silent Hill)        3.25527
# 70395                                        Fragile Line         3.9251
# 19831                                 Classic Man - Remix        3.91743
# 75702                               Vacations - 2010 Demo        12.4197
# 20847                                      Drive Me Crazy        4.80282
# 2111                        Santa Claus Is Coming To Town          2.318
# 57631         Album for the Young, Op. 68: 28. Erinnerung        1.88667
# 68269   Sweet Caroline (Boston Red Sox Ballpark Organ ...       0.680833
# 65476                                        Take Me Home        3.06018
# 84475                                      The Rat Patrol        1.73955
# 78215                                Mazhai Vara Pogudhae        5.70912
# 41616                                            Thresher        6.95255
# 24341       Chopin: 24 Preludes, Op. 28: No. 2 in A Minor        2.07533
# 69577                                                 Way        2.56667
# 101089                                         Conception         4.0575
# 53260                                       Por Esos Ojos        3.14955
# 67807                      I Am A Gummy Bear (2015 Remix)        2.38487
# 61400                                        She's Desire        3.18377
# 29105                                             Feel It         4.7931
# 67373         Rumbling Lake Waves with the Tide Coming In        1.19525
# 96831                                       Don't Miss It          3.358
# 100848                                        Black Peter        3.81502
# 27300                                            Pitseleh        2.88088
# 36944                                        Wishing Away         3.8397
# 46007        Do They Know It's Christmas (Feed the World)        4.11688
# ...                                                   ...            ...
# 8601                                               Inhale        3.17883
# 51624                                        Gagan Parikh        4.42732
# 24011                                         Couch Party        1.76278
# 27117                                         Set Trippin        3.86888
# 15673                          Put That Pride to the Side        3.24707
# 25                                      Can’t Take A Joke         2.7329
# 57296                                 Ennemis - bonus rap        3.90688
# 4287                                           last piece        3.08867
# 51526                        Underwater - Tinlicker Remix         8.0931
# 44844                                          Matriarchy       0.508067
# 66320                                        New Cultures        1.10367
# 31303                                         Cry No More        4.37443
# 42583                                       How We Livin'        3.61882
# 5597                                         Like a Dream        4.80088
# 67611                   Ode To C.C. - Part 1 [Remastered]       0.763333
# 15853                                    The Love We Make          4.654
# 55109                                  Kadhal Oru Aagayam        2.69603
# 46653                                                파란 봄         4.1947
# 51467                                         Mr. Tillman        3.05887
# 22604                                            I Forgot        3.06772
# 1398                                              Too Lit         3.2653
# 52780                                       Swoon:Stagger        3.42857
# 59502                                                 Joy        3.26615
# 51717    I Believe In You, You should too, Believe in You         2.8728
# 18133                                          Beat Quest        6.06822
# 35165                                            Mi Noche        2.58267
# 15665                                             Gee Pac        3.26437
# 49501                                                Rush        1.91085
# 67565   Aake Seedhi Lage Dil Pe Jaise (From "Half Tick...        3.68043
# 5587                                              Runaway        4.43888
#
#                      artist_id                album_id  track_genre_top  \
# 64851   27hSR8e34ZM5vj5fUFixyb  0QlGRL8MgEErqJW4a02iWk              NaN
# 84465   7pZPJvNcF3seJ8lHPfNwEA  66jOHevrhZbt8CWLmERUA9              NaN
# 4042    099toTcKJoywTosZr2hHjy  77UiJMD9OVYj2YXr2gO9L5              NaN
# 82084   1Cb9Edoxp02mgY0VWVlwQo  05dDeQ6BITiw2hjuXxjBcU              NaN
# 55396   6bebPrkEPr2xEkiHP3QkNT  3jz23zr9FLsqJAC9hNpbxX              NaN
# 55052   7zdmbPudNX4SQJXnYIuCTC  218XV2o9997yzQZr2NA5Xr              NaN
# 70395   7lAi1Cv19DsukgGjbZQxFg  1KTtC7NK3AaIcQpOmC1NsH              NaN
# 19831   4TsHKU8l8Wq7n7OPVikirn  0b2j47HuTRqlzvROQktVtg              NaN
# 75702   2Dr2zHoPEuASW1kOODc5I2  0mxli2Cs2vyf9PQenKM70L              NaN
# 20847   6DvlemMOlMH6VD9tB7BPRf  2iW0Ey7bbLqOGicMDPo4yM              NaN
# 2111    5V0MlUE1Bft0mbLlND7FJz  3cfRNKKs0by89V5C1uPDm3              NaN
# 57631   2UqjDAXnDxejEyE0CzfUrZ  0zAGryVqIFExsM17ayKDQr              NaN
# 68269   2ABt5stAk4zxKSu84pWoZy  4Fgkw1KVXYYJfgrWTrcEir              NaN
# 65476   5guWRMBbxErzvz11GlmTWF  3wFPn9rnEycGjqUcF1CfJb              NaN
# 84475   7pZPJvNcF3seJ8lHPfNwEA  66jOHevrhZbt8CWLmERUA9              NaN
# 78215   29aw5YCdIw2FEXYyAJZI8l  38er9gISOMI0uQW90und0K              NaN
# 41616   1M3BVQ36cqPQix8lQNCh4K  1s4Zqst1hslFx9CIrLI9dx              NaN
# 24341   7y97mc3bZRFXzT2szRM4L4  4aaqfEizAN4hvpGdKtvGZa              NaN
# 69577   54pzZYU7PNFAN1O5H715fk  1T7zqT5lZEmbgc0QgyclSk              NaN
# 101089  6AKWjx5wmOI3bCeLrxFjgv  4kXgqbJhqQw3ZUfQVEOOmV              NaN
# 53260   2WI2ub4Nn8cJM70m9IM2Hz  7ARafZyz3I2D7aI2DsTF5P              NaN
# 67807   6NJb7ZCMVLu2ZXwWJa2O3G  2t53vHcZLns0nW24Vmd6z3              NaN
# 61400   6VOaUBrKfzd49nIAzjVKmm  2AIjGgi7S3zWimTIekSxYj              NaN
# 29105   01pKrlgPJhm5dB4lneYAqS  44OSVbfmYeai7d1Euvqwpx              NaN
# 67373   52W8m0S2k3aylPySPrUo6S  4DmYg3CZyM9j1RJ8jwvgii              NaN
# 96831   2JmEwYg4sv7a7IkQ3wVoh6  3LNykpAt9iBdhNuC1Ky8oc              NaN
# 100848  6qIXmxBaIo8fXrURzqQAVE  17lzCLhI2PFjB9ExyjA53v              NaN
# 27300   5zVH7DKFtamUeGnLZHlPsW  53bdEtmOKTMdc8DOhiPWp1              NaN
# 36944   2bNoMMVO2QO6vySQvjn50L  7a0iAxTCisEXzvEfITBM3L              NaN
# 46007   7cWYiQSZ539WESH50bBgMp  4Xgbrg5lv7FMUmhBiE8KHs              NaN
# ...                        ...                     ...              ...
# 8601    61lyPtntblHJvA7FMMhi7E  6jkvWfbXl5So9U9IHtuFVD              NaN
# 51624   72hYRo7a1WKY5I2Ul14CRH  2bCl9g8r7NnyVDPLFULEnx              NaN
# 24011   3SGLeWc7J5Ve0CinAOrb3a  3qVyCSXCEAw3vqtbjc0BFU              NaN
# 27117   6dXsR7VDJvXnF1LTZlwULx  576RV4aBKFPKgCeYkGvK0t              NaN
# 15673   3XoL50Yt7zsdLJEKXNqBsS  63Ri6LuS8azmuM5lTTIJ2W              NaN
# 25      3TVXtAsR1Inumwj472S9r4  1ATL5GLyefJaxhQzSPVrLX              NaN
# 57296   6QS84S3i4gwdEKqWoTtDLd  53BmgQGkNj2Qbuk8dKQzTw              NaN
# 4287    6oBm8HB0yfrIc9IHbxs6in  28AjCPTvrM4gQIiwo0CEOE              NaN
# 51526   64KfnYe81Wld2AkG4bkGIV  4OscmT7DhzxIABCwr0mtSt              NaN
# 44844   1jsLx7iN8fyU7AWOUAlBBV  79tr1k3vwmo8qchfyw4Tfs              NaN
# 66320   3lknO6zCqvVnJArorgCxcg  7kc8KA6plwjSRPkqTI2Uwy              NaN
# 31303   34mu675oQQ5ZNuK1soZrIn  6uqgNfRltyZuGzFhMF256y              NaN
# 42583   4pORMflJEUW1OYfNgiMLH5  0F39jG5k0HGGtmBvNBzJyK              NaN
# 5597    5nM5pj6cEIkzCkwBJZibHK  3Jm9xunslITwDjh7Kn7TwQ              NaN
# 67611   16eRpMNXSQ15wuJoeqguaB  0VdmRMRZtYL3yEj9Cm5bUJ              NaN
# 15853   5a2EaR3hamoenG9rDuVn8j  0CEHFvHUQ0ZSv3mugziS76              NaN
# 55109   7zFBW2JxM4bgTTKxCRcS8Q  6iiGyjdV6vQ5aQTw872aDS              NaN
# 46653   3uGFTJ7JMllvhgGpumieHF  5zfvPWlLE1LpYewbAejTgX              NaN
# 51467   2kGBy2WHvF0VdZyqiVCkDT  7iIaGQrDi1z0rZa4B1ezS0              NaN
# 22604   6RHKEd9dpzQ4c09x8Zdaxu  4rAdbBvg2N19d7YfUMztUA              NaN
# 1398    6AUl0ykLLpvTktob97x9hO  4xbBdnb59ariAF5s06juqS              NaN
# 52780   6ZGf9hyQy1jpBZFb7nBWcP  5CQQdTLBwHHgdR5vSsth5b              NaN
# 59502   6c9vJcmxlffRozEkFTLUXG  3u6ZRKzM2P5InfeRMwqO3J              NaN
# 51717   0obuUG86gXYcMtRMNKaYKL  6yflf9fArPW7cp6pqAkPyF              NaN
# 18133                      305  2C3Ra3VEttQOdzf4oYFTbn              NaN
# 35165   37UACiDcdzEYii0iU0QpAf  17WPljPwx1adeqpsyeKPVy              NaN
# 15665   3XoL50Yt7zsdLJEKXNqBsS  63Ri6LuS8azmuM5lTTIJ2W              NaN
# 49501   0imE3buPhAowREqCrr4CYe  0sP1t8fB0EmQM6Xg9EAedr              NaN
# 67565   0GF4shudTAFv8ak9eWdd4Y  7hJJJsU0AS5dMOdyxDfUhQ              NaN
# 5587    3bhu7P5PfngueRHiB9hjcx  0YYboPBsKcVDrXiNfNIi7o              NaN
#
#        track_genres_all  track_language track_listens  \
# 64851                []             NaN          9926
# 84465                []             NaN             2
# 4042                 []             NaN          5677
# 82084                []             NaN         10539
# 55396                []             NaN          4730
# 55052                []             NaN          1654
# 70395                []             NaN         23304
# 19831                []             NaN         82309
# 75702                []             NaN           212
# 20847                []             NaN            72
# 2111                 []             NaN        185570
# 57631                []             NaN           156
# 68269                []             NaN            27
# 65476                []             NaN           303
# 84475                []             NaN             5
# 78215                []             NaN          1104
# 41616                []             NaN          7579
# 24341                []             NaN           689
# 69577                []             NaN         14616
# 101089               []             NaN          1505
# 53260                []             NaN             2
# 67807                []             NaN           664
# 61400                []             NaN          1641
# 29105                []             NaN          6268
# 67373                []             NaN           819
# 96831                []             NaN           411
# 100848               []             NaN           130
# 27300                []             NaN          8549
# 36944                []             NaN          4632
# 46007                []             NaN            33
# ...                 ...             ...           ...
# 8601                 []             NaN         62245
# 51624                []             NaN           138
# 24011                []             NaN          2589
# 27117                []             NaN          7207
# 15673                []             NaN           221
# 25                   []             NaN        192688
# 57296                []             NaN            53
# 4287                 []             NaN        132215
# 51526                []             NaN          4174
# 44844                []             NaN             4
# 66320                []             NaN           NaN
# 31303                []             NaN          2968
# 42583                []             NaN            16
# 5597                 []             NaN          6938
# 67611                []             NaN           104
# 15853                []             NaN         20555
# 55109                []             NaN           144
# 46653                []             NaN           NaN
# 51467                []             NaN        292212
# 22604                []             NaN         23802
# 1398                 []             NaN          3531
# 52780                []             NaN           395
# 59502                []             NaN          1019
# 51717                []             NaN            79
# 18133                []             NaN         11223
# 35165                []             NaN           425
# 15665                []             NaN           136
# 49501                []             NaN           136
# 67565                []             NaN            17
# 5587                 []             NaN          2386
#
#                                                track_tags  danceability  \
# 64851   [jazz, favorite songs, bebop, jazz instrumenta...         0.393
# 84465                                                  []         0.440
# 4042    [folk, acoustic, americana, afternoon, morning...         0.740
# 82084                                                  []         0.501
# 55396                                                  []         0.797
# 55052                                                  []         0.387
# 70395   [post-hardcore, metalcore, rock, emo, Progress...         0.442
# 19831   [Hip-Hop, rnb, 10s, 2015, kendrick lamar, rnba...         0.851
# 75702                                                  []         0.264
# 20847                                                  []         0.625
# 2111    [christmas, jazz, xmas, Christmas Music, x-mas...         0.592
# 57631                                                  []         0.371
# 68269                                                  []         0.837
# 65476                                                  []         0.631
# 84475                                                  []         0.690
# 78215                                                  []         0.835
# 41616                                                  []         0.362
# 24341                                                  []         0.324
# 69577                                                  []         0.439
# 101089                                                 []         0.395
# 53260                                                  []         0.659
# 67807                                                  []         0.839
# 61400                                                  []         0.502
# 29105                                                  []         0.645
# 67373                                                  []         0.272
# 96831                                                  []         0.453
# 100848                                                 []         0.618
# 27300                                                  []         0.611
# 36944                                                  []         0.650
# 46007                                                  []         0.781
# ...                                                   ...           ...
# 8601                                                   []         0.741
# 51624                                                  []         0.810
# 24011                                                  []         0.440
# 27117                                                  []         0.485
# 15673                                                  []         0.763
# 25            [Hip-Hop, rap, Canadian, Drake, like a lot]         0.761
# 57296                                                  []         0.458
# 4287    [indie, alternative, indie pop, socorro, um ti...         0.582
# 51526                                                  []         0.633
# 44844                                                  []         0.622
# 66320                                                  []         0.427
# 31303                                                  []         0.535
# 42583                                                  []         0.848
# 5597                                                   []         0.436
# 67611                                                  []         0.332
# 15853   [Ballad, soul, prince, rnb, funk, beautiful, 9...         0.560
# 55109                                                  []         0.488
# 46653                                                  []         0.540
# 51467                             [rock, fip, fallon, iv]         0.473
# 22604                     [female vocalists, 2018 single]         0.724
# 1398                                                   []         0.739
# 52780                                                  []         0.783
# 59502                                                  []         0.521
# 51717                                                  []         0.578
# 18133                                                  []         0.419
# 35165                                                  []         0.839
# 15665                                                  []         0.664
# 49501                                                  []         0.604
# 67565                                                  []         0.569
# 5587                                                   []         0.650
#
#          energy  valence  song_currency song_hotness          spoti_track_id  \
# 64851   0.51100   0.2740            NaN         0.03  32WCcSindDy2AKj1IdV2aE
# 84465   0.47000   0.9650            NaN         0.01  0aOoS0SpzGRnDXmuVbiCPZ
# 4042    0.45300   0.6100            NaN         0.26  6g7amHSbqmmk7fpViGqXb3
# 82084   0.81400   0.2320            NaN         0.19  60OwwNiAIeoe8533hk0USo
# 55396   0.44400   0.8770            NaN         0.19  41eHsMDXaqizJxLYI9AkFa
# 55052   0.77300   0.0650            NaN         0.21  3QesnFSEEgZ1wwyox1ne1f
# 70395   0.99600   0.0704            NaN         0.23  1PXIsSyC3YSAtuI0U9dTRk
# 19831   0.65700   0.6440            NaN         0.52  530J9GupahE2O4a1iVkQxB
# 75702   0.97700   0.3200            NaN         0.03  0qNbCmjavn69YUdV4c1BDn
# 20847   0.69200   0.3230            NaN         0.28  5HhQMt1RKJZCY1FbNw6Od6
# 2111    0.48200   0.8730            NaN         0.38  00z2Nm4cLt0mIKOGF6uZfl
# 57631   0.03650   0.2780            NaN         0.06  3HMXjw4O10Fz3yTTZpNrmX
# 68269   0.32400   0.8480            NaN         0.22  3onluLeinePPcyzD2LdNHX
# 65476   0.84800   0.7330            NaN         0.06  5CSDxDQtEA3oWJzByQRi0i
# 84475   0.43100   0.5780            NaN         0.04  5B78uuKzDVzOh4iUfE1ySz
# 78215   0.73900   0.6750            NaN         0.28  5ich0wSxDxMryEjwZo6XzG
# 41616   0.31700   0.0497            NaN         0.17  09pndptriN0JkMSkGVpqGd
# 24341   0.00349   0.0540            NaN         0.09  3TpRg6slHq8FBa4zoqE6Pq
# 69577   0.55900   0.0597            NaN         0.13  2WemESiMErYvMjvJ1biqHN
# 101089  0.70500   0.2010            NaN          0.1  3Z4bS2ASZuYYt7KsvRPvxQ
# 53260   0.63400   0.8070            NaN         0.14  673vzVv1oakQB3DmTZTIB4
# 67807   0.85500   0.6760            NaN         0.33  4fFWKcB0x0aKAq18LvEYf5
# 61400   0.86400   0.3020            NaN         0.27  5PIn3fUqldKcNA2nMFLGfR
# 29105   0.94500   0.1360            NaN         0.17  5FpdDLWtWBuqngEEcq2Pg4
# 67373   0.98400   0.0226            NaN         0.02  2ztG2mzaBr65XWQR2WUGm0
# 96831   0.78700   0.6480            NaN         0.19  7ElqtwxhSQbBTgnn8o3Q2A
# 100848  0.74500   0.5990            NaN         0.09  11MJ2frnel6kutVlFSQm1h
# 27300   0.22800   0.4360            NaN          0.2  26PeMFQLMwaLwc5KhIkeWg
# 36944   0.41100   0.2460            NaN         0.11  5Zo6BAGPRLeTFx0Z0y4usT
# 46007   0.13300   0.2790            NaN         0.21  162eGiet5rEIiTTcL50qTw
# ...         ...      ...            ...          ...                     ...
# 8601    0.81400   0.4760            NaN         0.65  05bUAkDRK3xzvVkZlGU6ee
# 51624   0.37100   0.3090            NaN         0.29  6jJljsgRRpyuXKxZGeW6Vy
# 24011   0.95600   0.9600            NaN         0.33  4DHHDoVqLylUi1KBTtgytf
# 27117   0.78600   0.3370            NaN         0.49  6neCPzADon669Mxe4oZSlR
# 15673   0.55400   0.3510            NaN          0.4  25NyJoTBGJHVFTfw4J1ONU
# 25      0.59800   0.4470            NaN         0.76  1dUHF4RyMmMTveJ0Rby6Xm
# 57296   0.74700   0.6930            NaN         0.28  4Au6ZWmhUr3iLMzcjvg9cu
# 4287    0.47000   0.2050            NaN         0.54  2Z8SpRWDcWCrRBBoX6z80Z
# 51526   0.87300   0.1860            NaN         0.19  5RPTJWrqbU5DK2O5MAbUHN
# 44844   0.20400   0.1730            NaN         0.28  4RXbeqy6x25h4xCYNHp4dc
# 66320   0.00972   0.2750            NaN         0.14  039Doul5oJK7LoMmwj0MD4
# 31303   0.61600   0.6820            NaN         0.39  7riVWDCXzmFlOjhFzkr3ed
# 42583   0.47200   0.6730            NaN         0.24  4MAMTDNaTiFrdWkO9gxj2a
# 5597    0.42100   0.2530            NaN         0.41  5iXW7gPQuDz5GCVJT8fjJl
# 67611   0.59600   0.6280            NaN         0.13  4upqEezZn96B2A8nLdHKQw
# 15853   0.61600   0.1870            NaN         0.35  4sOFRu2UsAlYnFZOw06glP
# 55109   0.58500   0.3990            NaN         0.46  6EwRpLL5QThnF2k1sZzQpC
# 46653   0.53500   0.2160            NaN         0.51  0KpXBGMi5TPHu8cJGWvNBb
# 51467   0.60900   0.5230            NaN         0.48  5ArtaQ740g1HgDugVOyzf7
# 22604   0.51100   0.6520            NaN         0.57  6p3MquVmVPXgH5WrRYoTL8
# 1398    0.66800   0.2410            NaN         0.54  0dY2cWiCvcBs6lW5UOAOIB
# 52780   0.64400   0.6820            NaN         0.41  5MIUtrizeyaYjpKwKCWJ5C
# 59502   0.35200   0.0700            NaN         0.38  6iXRiBqfLeZClOJsGqRazw
# 51717   0.69400   0.6690            NaN         0.19  0u5Mj8mkmdxwjERBFRq4QO
# 18133   0.88600   0.3450            NaN         0.35  4rPtxv6E6qAdtJoTko4Cef
# 35165   0.88300   0.8210            NaN          0.3  37dHBMBKyHrxpFbxBmkYgA
# 15665   0.65800   0.0944            NaN         0.38  1mmH9ECjDEylMivA5Q34CW
# 49501   0.14200   0.0617            NaN         0.25  3TbcNUywObI43xqo2dLaX8
# 67565   0.66800   0.8060            NaN         0.09  5HmFxJMotmP3ZUCyh9AY0j
# 5587    0.69000   0.4910            NaN         0.43  6seVUEUDm3XQYkWqK1vWiW
#
#                 spoti_album_id         spoti_artist_id
# 64851   0QlGRL8MgEErqJW4a02iWk  27hSR8e34ZM5vj5fUFixyb
# 84465   66jOHevrhZbt8CWLmERUA9  7pZPJvNcF3seJ8lHPfNwEA
# 4042    77UiJMD9OVYj2YXr2gO9L5  099toTcKJoywTosZr2hHjy
# 82084   05dDeQ6BITiw2hjuXxjBcU  1Cb9Edoxp02mgY0VWVlwQo
# 55396   3jz23zr9FLsqJAC9hNpbxX  6bebPrkEPr2xEkiHP3QkNT
# 55052   218XV2o9997yzQZr2NA5Xr  7zdmbPudNX4SQJXnYIuCTC
# 70395   1KTtC7NK3AaIcQpOmC1NsH  7lAi1Cv19DsukgGjbZQxFg
# 19831   0b2j47HuTRqlzvROQktVtg  4TsHKU8l8Wq7n7OPVikirn
# 75702   0mxli2Cs2vyf9PQenKM70L  2Dr2zHoPEuASW1kOODc5I2
# 20847   2iW0Ey7bbLqOGicMDPo4yM  6DvlemMOlMH6VD9tB7BPRf
# 2111    3cfRNKKs0by89V5C1uPDm3  5V0MlUE1Bft0mbLlND7FJz
# 57631   0zAGryVqIFExsM17ayKDQr  2UqjDAXnDxejEyE0CzfUrZ
# 68269   4Fgkw1KVXYYJfgrWTrcEir  2ABt5stAk4zxKSu84pWoZy
# 65476   3wFPn9rnEycGjqUcF1CfJb  5guWRMBbxErzvz11GlmTWF
# 84475   66jOHevrhZbt8CWLmERUA9  7pZPJvNcF3seJ8lHPfNwEA
# 78215   38er9gISOMI0uQW90und0K  29aw5YCdIw2FEXYyAJZI8l
# 41616   1s4Zqst1hslFx9CIrLI9dx  1M3BVQ36cqPQix8lQNCh4K
# 24341   4aaqfEizAN4hvpGdKtvGZa  7y97mc3bZRFXzT2szRM4L4
# 69577   1T7zqT5lZEmbgc0QgyclSk  54pzZYU7PNFAN1O5H715fk
# 101089  4kXgqbJhqQw3ZUfQVEOOmV  6AKWjx5wmOI3bCeLrxFjgv
# 53260   7ARafZyz3I2D7aI2DsTF5P  2WI2ub4Nn8cJM70m9IM2Hz
# 67807   2t53vHcZLns0nW24Vmd6z3  6NJb7ZCMVLu2ZXwWJa2O3G
# 61400   2AIjGgi7S3zWimTIekSxYj  6VOaUBrKfzd49nIAzjVKmm
# 29105   44OSVbfmYeai7d1Euvqwpx  01pKrlgPJhm5dB4lneYAqS
# 67373   4DmYg3CZyM9j1RJ8jwvgii  52W8m0S2k3aylPySPrUo6S
# 96831   3LNykpAt9iBdhNuC1Ky8oc  2JmEwYg4sv7a7IkQ3wVoh6
# 100848  17lzCLhI2PFjB9ExyjA53v  6qIXmxBaIo8fXrURzqQAVE
# 27300   53bdEtmOKTMdc8DOhiPWp1  5zVH7DKFtamUeGnLZHlPsW
# 36944   7a0iAxTCisEXzvEfITBM3L  2bNoMMVO2QO6vySQvjn50L
# 46007   4Xgbrg5lv7FMUmhBiE8KHs  7cWYiQSZ539WESH50bBgMp
# ...                        ...                     ...
# 8601    6jkvWfbXl5So9U9IHtuFVD  61lyPtntblHJvA7FMMhi7E
# 51624   2bCl9g8r7NnyVDPLFULEnx  72hYRo7a1WKY5I2Ul14CRH
# 24011   3qVyCSXCEAw3vqtbjc0BFU  3SGLeWc7J5Ve0CinAOrb3a
# 27117   576RV4aBKFPKgCeYkGvK0t  6dXsR7VDJvXnF1LTZlwULx
# 15673   63Ri6LuS8azmuM5lTTIJ2W  3XoL50Yt7zsdLJEKXNqBsS
# 25      1ATL5GLyefJaxhQzSPVrLX  3TVXtAsR1Inumwj472S9r4
# 57296   53BmgQGkNj2Qbuk8dKQzTw  6QS84S3i4gwdEKqWoTtDLd
# 4287    28AjCPTvrM4gQIiwo0CEOE  6oBm8HB0yfrIc9IHbxs6in
# 51526   4OscmT7DhzxIABCwr0mtSt  64KfnYe81Wld2AkG4bkGIV
# 44844   79tr1k3vwmo8qchfyw4Tfs  1jsLx7iN8fyU7AWOUAlBBV
# 66320   7kc8KA6plwjSRPkqTI2Uwy  3lknO6zCqvVnJArorgCxcg
# 31303   6uqgNfRltyZuGzFhMF256y  34mu675oQQ5ZNuK1soZrIn
# 42583   0F39jG5k0HGGtmBvNBzJyK  4pORMflJEUW1OYfNgiMLH5
# 5597    3Jm9xunslITwDjh7Kn7TwQ  5nM5pj6cEIkzCkwBJZibHK
# 67611   0VdmRMRZtYL3yEj9Cm5bUJ  16eRpMNXSQ15wuJoeqguaB
# 15853   0CEHFvHUQ0ZSv3mugziS76  5a2EaR3hamoenG9rDuVn8j
# 55109   6iiGyjdV6vQ5aQTw872aDS  7zFBW2JxM4bgTTKxCRcS8Q
# 46653   5zfvPWlLE1LpYewbAejTgX  3uGFTJ7JMllvhgGpumieHF
# 51467   7iIaGQrDi1z0rZa4B1ezS0  2kGBy2WHvF0VdZyqiVCkDT
# 22604   4rAdbBvg2N19d7YfUMztUA  6RHKEd9dpzQ4c09x8Zdaxu
# 1398    4xbBdnb59ariAF5s06juqS  6AUl0ykLLpvTktob97x9hO
# 52780   5CQQdTLBwHHgdR5vSsth5b  6ZGf9hyQy1jpBZFb7nBWcP
# 59502   3u6ZRKzM2P5InfeRMwqO3J  6c9vJcmxlffRozEkFTLUXG
# 51717   6yflf9fArPW7cp6pqAkPyF  0obuUG86gXYcMtRMNKaYKL
# 18133   2C3Ra3VEttQOdzf4oYFTbn  3qYfqdVwX0fil71onLpLkh
# 35165   17WPljPwx1adeqpsyeKPVy  37UACiDcdzEYii0iU0QpAf
# 15665   63Ri6LuS8azmuM5lTTIJ2W  3XoL50Yt7zsdLJEKXNqBsS
# 49501   0sP1t8fB0EmQM6Xg9EAedr  0imE3buPhAowREqCrr4CYe
# 67565   7hJJJsU0AS5dMOdyxDfUhQ  0GF4shudTAFv8ak9eWdd4Y
# 5587    0YYboPBsKcVDrXiNfNIi7o  3bhu7P5PfngueRHiB9hjcx
#
# [178504 rows x 18 columns]

# %%
if CLEAN_PHASE:
    albums_df = pd.concat([albums_df, albums_post], axis=0,
                          sort=False)
    albums_df.drop_duplicates('album_id', inplace=True)
    albums_df.drop(columns=['spoti_album_id'], inplace=True)
    albums_df['album_listens'] = pd.to_numeric(albums_df['album_listens'])
    
    
    artists_df = pd.concat([artists_df, artists_post], axis=0, 
                           sort=False)
    artists_df.drop_duplicates('artist_id', inplace=True)
    artists_df.drop(columns=['spoti_artist_id', 'artist_name_x', 
                             'artist_longitude_x', 'artist_latitude_x'], 
                    inplace=True)
    artists_df.rename({'artist_latitude_y': 'artist_latitude', 
                       'artist_longitude_y': 'artist_longitude',
                       'artist_name_y': 'artist_name'}, 
                      axis='columns', 
                      inplace=True)
    
    
    tracks_df = pd.concat([tracks_df, tracks_post], axis=0, 
                           sort=False)
    tracks_df.drop_duplicates('track_id', inplace=True)
    tracks_df.drop(columns=['spoti_track_id', 'spoti_album_id',
                            'spoti_artist_id', 'track_genres_all', 
                            'track_genre_top'], inplace=True)
    tracks_df['track_duration'] = pd.to_numeric(tracks_df['track_duration'])
    tracks_df['track_listens'] = pd.to_numeric(tracks_df['track_listens'])
    tracks_df['song_hotness'] = pd.to_numeric(tracks_df['song_hotness'])
    
    
    track_genre_rel_df = pd.concat([track_genre_rel_df, track_genre_rel_post], 
                                   axis=0, sort=False)
    track_genre_rel_df.drop_duplicates(subset=['track_id', 'genre_id'], 
                                       inplace=True)
    track_genre_rel_df['genre_id'] = pd.to_numeric(track_genre_rel_df['genre_id'])

# %% [markdown]
# Finally, after all preprocessing steps, we can save the information to be used for our analysis.

# %%
# Read  and wirte files depending on the existance of own path
genres_df_path = '{dir}{file}'.format(dir=PKL_DIR, 
                                     file='genres_df.pkl')
albums_df_path = '{dir}{file}'.format(dir=PKL_DIR, 
                                     file='albums_df.pkl')
artists_df_path = '{dir}{file}'.format(dir=PKL_DIR, 
                                     file='artists_df.pkl')
tracks_df_path = '{dir}{file}'.format(dir=PKL_DIR, 
                                      file='tracks_df.pkl')
track_genre_rel_df_path = '{dir}{file}'.format(dir=PKL_DIR, 
                                               file='track_genre_rel_df.pkl')
if CLEAN_PHASE:
    genres_df.to_pickle(genres_df_path)
elif os.path.exists(genres_df_path):
    genres_df = pd.read_pickle(genres_df_path)
else:
    print('There is no genres pandas data')
    
if CLEAN_PHASE:
    albums_df.to_pickle(albums_df_path)
elif os.path.exists(albums_df_path):
    albums_df = pd.read_pickle(albums_df_path)
else:
    print('There is no albums pandas data')
    
if CLEAN_PHASE:
    artists_df.to_pickle(artists_df_path)
elif os.path.exists(artists_df_path):
    artists_df = pd.read_pickle(artists_df_path)
else:
    print('There is no artists pandas data')
    
if CLEAN_PHASE:
    tracks_df.to_pickle(tracks_df_path)
elif os.path.exists(tracks_df_path):
    tracks_df = pd.read_pickle(tracks_df_path)
else:
    print('There is no tracks pandas data')
    
if CLEAN_PHASE:
    track_genre_rel_df.to_pickle(track_genre_rel_df_path)
elif os.path.exists(track_genre_rel_df_path):
    track_genre_rel_df = pd.read_pickle(track_genre_rel_df_path)
else:
    print('There is no tracks-genres pandas data')

# %% [markdown]
# We identify some statistics on all dataframes, like the missing values after preprocessing, taking echonest as one dataframe, just for analysis.

# %%
pretty_print(genres_df, 'Genres', DEBUG)
# Out:
# Genres size: 163
#
# NaN count by column:
# genre_id        0
# #tracks         0
# parent          0
# title           0
# top_level       0
# genre_parent    0
# dtype: int64
#    genre_id  #tracks  parent          title  top_level   genre_parent
# 0         1     8693      38    Avant-Garde         38   Experimental
# 1         2     5271       0  International          2  International
# 2         3     1752       0          Blues          3          Blues
# 3         4     4126       0           Jazz          4           Jazz
# 4         5     4106       0      Classical          5      Classical

# %%
pretty_print(artists_df, 'Artists', DEBUG)
# Out:
# Artists size: 21966
#
# NaN count by column:
# artist_id               0
# artist_discovery    19090
# city                18130
# state               18130
# country             18130
# artist_family       19090
# artist_hotness      13465
# artist_latitude     18130
# artist_longitude    18130
# artist_name             0
# dtype: int64
#   artist_id  artist_discovery          city         state country  \
# 0         1          0.388990     Lakehurst    New Jersey      US
# 1         6          0.557339           NaN           NaN     NaN
# 2        54          0.388923    Providence  Rhode Island      US
# 3        56          0.252381    Providence  Rhode Island      US
# 4        60          0.262717  Philadelphia  Pennsylvania      US
#
#   artist_family artist_hotness artist_latitude artist_longitude  \
# 0       0.38674        0.40637         40.0583         -74.4057
# 1      0.614272       0.798387             NaN              NaN
# 2      0.330784         0.4063          41.824         -71.4128
# 3      0.238153       0.263657          41.824         -71.4128
# 4      0.173315       0.274455         39.9523         -75.1638
#
#                        artist_name
# 0                             AWOL
# 1                        Kurt Vile
# 2  Alec K. Redfearn & the Eyesores
# 3                 Amoebic Ensemble
# 4                   Arc and Sender

# %%
pretty_print(albums_df, 'Albums', DEBUG)
# Out:
# Albums size: 19621
#
# NaN count by column:
# album_id                  0
# album_date_created     5226
# album_date_released    5404
# album_title               1
# album_listens            34
# dtype: int64
#   album_id   album_date_created album_date_released            album_title  \
# 0        1  2008-11-26 01:44:45          2009-01-05   AWOL - A Way Of Life
# 1        6  2008-11-26 01:45:08          2008-02-06      Constant Hitmaker
# 2       60  2008-11-26 01:49:57          2009-01-16  Every Man For Himself
# 3       61  2008-11-26 01:49:59          2007-05-22         The Blind Spot
# 4       62  2008-11-26 01:50:03          2005-01-25         The Quiet Room
#
#    album_listens
# 0         6073.0
# 1        47632.0
# 2         1304.0
# 3         1300.0
# 4          845.0

# %%
pretty_print(tracks_df, 'Tracks', DEBUG)
# Out:
# Tracks size: 285078
#
# NaN count by column:
# track_id               0
# track_title            1
# track_duration         0
# artist_id              0
# album_id               0
# track_language    270054
# track_listens      14409
# track_tags             0
# danceability       93445
# energy             93445
# valence            93445
# song_currency     271949
# song_hotness       93445
# dtype: int64
#   track_id   track_title  track_duration artist_id album_id track_language  \
# 0        2          Food           168.0         1        1             en
# 1        3  Electric Ave           237.0         1        1             en
# 2        5    This World           206.0         1        1             en
# 3       10       Freeway           161.0         6        6             en
# 4      134  Street Music           207.0         1        1             en
#
#    track_listens track_tags  danceability    energy   valence  song_currency  \
# 0         1293.0         []      0.675894  0.634476  0.576661       0.000000
# 1          514.0         []      0.528643  0.817461  0.269240       0.000000
# 2         1151.0         []      0.745566  0.701470  0.621661       0.000000
# 3        50135.0         []      0.658179  0.924525  0.963590       0.005158
# 4          943.0         []      0.513238  0.560410  0.894072       0.000000
#
#    song_hotness
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.354516
# 4      0.000000

# %%
pretty_print(track_genre_rel_df, 'Track-Genre', DEBUG)
# Out:
# Track-Genre size: 287767
#
# NaN count by column:
# track_id    0
# genre_id    0
# dtype: int64
#   track_id  genre_id
# 0        2        21
# 1        3        21
# 2        5        21
# 3       10        10
# 4       20        76
